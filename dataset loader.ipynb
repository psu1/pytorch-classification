# %%
import os
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import models.imagenet as customized_models

# %%
data_path = '/media/jaden/DeepLearningCode/data/tiny-imagenet-200'

# %%
# Data loading code
traindir = os.path.join(data_path, 'train')
valdir = os.path.join(data_path, 'val')
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(traindir, transforms.Compose([
            # transforms.Resize(256),
            # transforms.RandomSizedCrop(224),  # tiny imagenet 64x64
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=1, shuffle=True,
        num_workers=1, pin_memory=True)

# %%
print type(train_loader), '\n',  len(train_loader)
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>
# 100000

# %%
for batch_idx, (inputs, targets) in enumerate(train_loader):
    print ('batch_idx {} \t input {} \t output {}'. format(batch_idx, inputs.size(), targets.size()))
#     if batch_idx ==1:        
#         print('input {} \t output {}'. format(inputs, targets ))
# Out:
# batch_idx 0 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 1 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 2 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 3 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 4 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 5 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 6 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 7 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 8 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 9 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 10 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# batch_idx 11 	 input torch.Size([512, 3, 64, 64]) 	 output torch.Size([512])
# ...

# %%
196*512
# Out:
# 100352
